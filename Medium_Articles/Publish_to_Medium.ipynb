# %%
import jupyter_to_medium as jtm
jtm.publish('C:/Users/kevin/OneDrive/Upskill_Puthon_DS/Github_oneDrive/Medium/One_Hot_Encoding.ipynb',
            integration_token=None,
            pub_name=None,
            title=None,
            tags=None,
            publish_status='draft',
            notify_followers=False,
            license='all-rights-reserved',
            canonical_url=None,
            chrome_path=None,
            save_markdown=False,
            table_conversion='chrome',
            )
# Out:
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
# loading image to medium
#
#
# Image Storage Information from Medium
# -------------------------------------
#
# [
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*cutQfseeI7ri9Cj8sAf8RA.png",
#             "md5": "cutQfseeI7ri9Cj8sAf8RA"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*k4fI6NeguSt0cphesv0-9g.png",
#             "md5": "k4fI6NeguSt0cphesv0-9g"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*keB6im7txyZS0vihhIWpZw.png",
#             "md5": "keB6im7txyZS0vihhIWpZw"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*uzeO9IHXaHb5v-LlhLIqxA.png",
#             "md5": "uzeO9IHXaHb5v-LlhLIqxA"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*q-_HuSw7blzU4bvIbuqgLw.png",
#             "md5": "q-_HuSw7blzU4bvIbuqgLw"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*ivZVN7q8vaiqH0o5tAORqQ.png",
#             "md5": "ivZVN7q8vaiqH0o5tAORqQ"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*PQAs6d6_2tCZR5GRzHvUqA.png",
#             "md5": "PQAs6d6_2tCZR5GRzHvUqA"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*nSMVwTcvTNb017yLGeG1OQ.png",
#             "md5": "nSMVwTcvTNb017yLGeG1OQ"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*oYvbIsj3ZXLM1Rb_R--ebg.png",
#             "md5": "oYvbIsj3ZXLM1Rb_R--ebg"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*qz6memVMz7QCFVRJgP8UoQ.png",
#             "md5": "qz6memVMz7QCFVRJgP8UoQ"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*dA87BALNsWDNCi8hclN9UQ.png",
#             "md5": "dA87BALNsWDNCi8hclN9UQ"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*j2cPhreHDs1PDUtk4SDqfw.png",
#             "md5": "j2cPhreHDs1PDUtk4SDqfw"
#         }
#     },
#     {
#         "data": {
#             "url": "https://cdn-images-1.medium.com/proxy/1*YqzLZQ6hIaX2XhNmE1Bh7A.png",
#             "md5": "YqzLZQ6hIaX2XhNmE1Bh7A"
#         }
#     }
# ]
#
#
#
# Successfully posted to Medium!!!
# --------------------------------
# id                  8aaea7ba9af2
# title               One_Hot_Encoding
# authorId            13f4fb4e291608f5679f330b7b3b28be30d98d41c343412b4a8ff5933e38057dd
# url                 https://medium.com/@kevinprinsloo/8aaea7ba9af2
# canonicalUrl
# publishStatus       draft
# license             all-rights-reserved
# licenseUrl          https://policy.medium.com/medium-terms-of-service-9db0094a1e0f
# tags                []
# {'data': {'id': '8aaea7ba9af2',
#   'title': 'One_Hot_Encoding',
#   'authorId': '13f4fb4e291608f5679f330b7b3b28be30d98d41c343412b4a8ff5933e38057dd',
#   'url': 'https://medium.com/@kevinprinsloo/8aaea7ba9af2',
#   'canonicalUrl': '',
#   'publishStatus': 'draft',
#   'license': 'all-rights-reserved',
#   'licenseUrl': 'https://policy.medium.com/medium-terms-of-service-9db0094a1e0f',
#   'tags': []}}
